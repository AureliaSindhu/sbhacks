# %%
import os
import openai
import sycamore
from sycamore.transforms.partition import ArynPartitioner
from dotenv import load_dotenv

def process_pdf_return_tuple(file_name: str) -> tuple[list[float], str, str, str]:
    """
    Reads a PDF file via Sycamore, partitions its content, summarizes the text
    with an OpenAI model, and generates embeddings. Returns a tuple:
        ([embedding_vector], file_name, summary_text, entire_document_content).

    Args:
        file_name (str): The name (or path) of the PDF file to process.

    Returns:
        tuple: A tuple with the following elements:
            0) [embedding_vector] (list[float]): The embedding vector of the summary
            1) file_name (str): The original file name/path
            2) summary_text (str): The summarized text content
            3) entire_document_content (str): The full text content extracted from the PDF
    """
    # Load environment variables (e.g. ARYN_API_KEY, OpenAI keys, etc.)
    load_dotenv()
    
    # Initialize Sycamore context (only needs to be done once per session)
    context = sycamore.init()

    # 1) Read the PDF and partition
    docset = context.read.binary(
        paths=[file_name], 
        binary_format="pdf"
    ).partition(
        partitioner=ArynPartitioner(
            extract_table_structure=True,
            aryn_api_key=os.getenv("ARYN_API_KEY"),
            use_ocr=True,
            ocr_images=True
        )
    )

    # 2) Execute the partitioning
    docset.execute()

    # 3) Collect all documents
    documents = docset.take_all()

    # 4) Create a single string of the entire document content
    elements = documents[0].elements if documents else []
    lines = []
    for elem in elements:
        text_content = elem.get("text_representation", "")
        if text_content:
            # Optional formatting. You can adjust as needed.
            lines.append(f"[{elem['type']}]: {text_content}")
    entire_document_content = "\n".join(lines)

    # 5) Use an OpenAI model to summarize the document
    #    (Adjust the model, prompt, and parameters according to your usage.)
    prompt = (
        "Summarize the following lecture notes into one paragraph in detail; "
        "including the important key terms, key words, and key points:\n\n"
        f"{entire_document_content}"
    )

    try:
        response = openai.chat.completion.create(
            model="o1",  # or "o1-mini", or any other model you have access to
            messages=[{"role": "user", "content": prompt}],
            max_tokens=10000  # Adjust if needed
        )
        summary_text = response.choices[0].message.content.strip()
    except Exception as e:
        print("Error during summarization:", e)
        summary_text = ""

    # 6) Generate embeddings for the summarized text
    #    (You may need to adapt the model name for your embedding usage.)
    try:
        embedding_response = openai.embeddings.create(
            model="text-embedding-3-large",  # Example embedding model
            input=summary_text,
            encoding_format="float",         # Example parameter
        )
        embedding_vector = embedding_response.data[0].embedding
    except Exception as e:
        print("Error generating embedding:", e)
        embedding_vector = []

    # Return the tuple in the desired format
    return (embedding_vector, file_name, summary_text, entire_document_content)

# %%
file_names = ["data/Fluid Dynamics.pdf", "data/Lab Notes.pdf", "data/Light.pdf", "data/Oscillations.pdf", "data/Circuit.pdf"]
result = [process_pdf_return_tuple(x) for x in file_names]
# Out:
# 2025-01-12 05:23:15,519	WARNING util.py:587 -- The argument ``compute`` is deprecated in Ray 2.9. Please specify argument ``concurrency`` instead. For more information, see https://docs.ray.io/en/master/data/transforming-data.html#stateful-transforms.
# 2025-01-12 05:23:15,535	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in C:\Users\aurel\AppData\Local\Temp\ray\session_2025-01-11_19-27-00_140008_13532\logs\ray-data
# 2025-01-12 05:23:15,536	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary] -> ActorPoolMapOperator[Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap)]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadBinary->SplitBlocks(28) 1: 0.00 row [00:00, ? row/s]
#
# Running Dataset. Active & requested resources: 2/14 CPU, 265.7MB/2.5GB object store: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 9.7MB object store: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 9.7MB object store: : 1.00 row [00:01, 1.06s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 9.7MB object store: : 1.00 row [00:01, 1.06s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:02, 1.06s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:02, 1.06s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:07, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:03, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:08, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:03, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:04, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:09, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:04, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:05, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:10, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:05, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:06, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:11, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:07, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:12, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:07, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:08, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:13, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:08, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:09, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:14, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:09, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:10, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:15, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:10, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:11, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:17, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:11, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:12, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:18, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:12, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:13, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:19, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:13, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:14, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:20, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:14, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]:   0%|          | 0.00/14.0 [00:15<?, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]:  14%|█▍        | 2.00/14.0 [00:15<01:33, 7.82s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store:  14%|█▍        | 2.00/14.0 [00:21<02:08, 10.7s/ row]256.0MB object store; [locality off]:  14%|█▍        | 2.00/14.0 [00:15<01:33, 7.82s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 1.00 row [00:15, 1.06s/ row]
#
#
#
# ✔️  Dataset execution finished in 21.54 seconds: 100%|██████████| 2.00/2.00 [00:21<00:00, 10.8s/ row]
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 1.00 row [00:15, 1.06s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]:  14%|█▍        | 2.00/14.0 [00:15<01:33, 7.82s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 1.00 row [00:15, 1.06s/ row]
#
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 1.00 row [00:15, 15.9s/ row]
#
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]:  14%|█▍        | 2.00/14.0 [00:15<01:33, 7.82s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]:  14%|█▍        | 2.00/14.0 [00:15<01:33, 7.82s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:15<00:00, 7.82s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:15<00:00, 7.82s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:15<00:00, 7.96s/ row]
# 2025-01-12 05:23:37,211	WARNING util.py:587 -- The argument ``compute`` is deprecated in Ray 2.9. Please specify argument ``concurrency`` instead. For more information, see https://docs.ray.io/en/master/data/transforming-data.html#stateful-transforms.
# 2025-01-12 05:23:37,223	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in C:\Users\aurel\AppData\Local\Temp\ray\session_2025-01-11_19-27-00_140008_13532\logs\ray-data
# 2025-01-12 05:23:37,224	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary] -> ActorPoolMapOperator[Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap)]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadBinary->SplitBlocks(28) 1: 0.00 row [00:00, ? row/s]
#
# Running Dataset. Active & requested resources: 2/14 CPU, 265.7MB/2.5GB object store: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 9.7MB object store: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 9.7MB object store: : 1.00 row [00:01, 1.06s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 9.7MB object store: : 1.00 row [00:01, 1.06s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: : 1.00 row [00:02, 1.06s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.06s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.06s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:07, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:03<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:08, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:03, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:04<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:09, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:04, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:05<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:10, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:05, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:06<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:11, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:07<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:12, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:07, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:08<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:14, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:08, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:09<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:15, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:09, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:10<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:16, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:10, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:11<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:17, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:11, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:12<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:18, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:12, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:13<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:19, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:13, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:14<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:20, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:14, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:15<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:21, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:15, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:16<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:22, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:16, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:17<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:23, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:17, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:18<00:00, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 264.8MB/2.5GB object store: : 0.00 row [00:24, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:18, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:19<00:00, 1.06s/ row]
#
# ✔️  Dataset execution finished in 26.15 seconds: 100%|██████████| 2.00/2.00 [00:26<00:00, 13.1s/ row]5, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:19, ? row/s]
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 8.8MB object store: 100%|██████████| 1.00/1.00 [00:20<00:00, 1.06s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:20, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:20<00:00, 1.06s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:20<00:00, 1.06s/ row]
#
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:20<00:00, 20.6s/ row]
#
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:20, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: : 0.00 row [00:20, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]:   0%|          | 0.00/2.00 [00:20<?, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:20<00:00, 10.3s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:20<00:00, 10.3s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:20<00:00, 10.3s/ row]
# Error during summarization: 'Chat' object has no attribute 'completion'
# 2025-01-12 05:24:04,204	WARNING util.py:587 -- The argument ``compute`` is deprecated in Ray 2.9. Please specify argument ``concurrency`` instead. For more information, see https://docs.ray.io/en/master/data/transforming-data.html#stateful-transforms.
# 2025-01-12 05:24:04,219	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in C:\Users\aurel\AppData\Local\Temp\ray\session_2025-01-11_19-27-00_140008_13532\logs\ray-data
# 2025-01-12 05:24:04,220	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary] -> ActorPoolMapOperator[Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap)]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadBinary->SplitBlocks(28) 1: 0.00 row [00:00, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 0.0B/2.5GB object store: : 0.00 row [00:05, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 596.0KB object store: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 596.0KB object store: : 1.00 row [00:01, 1.04s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 596.0KB object store: : 1.00 row [00:01, 1.04s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 17; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
#
# Running Dataset. Active & requested resources: 2/14 CPU, 256.6MB/2.5GB object store: : 0.00 row [00:06, ? row/s] 17; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 544.1KB object store: : 1.00 row [00:02, 1.04s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 544.1KB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.04s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 544.1KB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.04s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 256.5MB/2.5GB object store: : 0.00 row [00:07, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 544.1KB object store: 100%|██████████| 1.00/1.00 [00:03<00:00, 1.04s/ row]
#
# ✔️  Dataset execution finished in 9.63 seconds: 100%|██████████| 2.00/2.00 [00:09<00:00, 4.84s/ row]08, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:03, ? row/s]
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 544.1KB object store: 100%|██████████| 1.00/1.00 [00:04<00:00, 1.04s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:04, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:04<00:00, 1.04s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:04<00:00, 4.08s/ row]
#
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:04, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: : 0.00 row [00:04, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]:   0%|          | 0.00/2.00 [00:04<?, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:04<00:00, 2.06s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:04<00:00, 2.06s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:04<00:00, 2.08s/ row]
# 2025-01-12 05:24:14,081	WARNING util.py:587 -- The argument ``compute`` is deprecated in Ray 2.9. Please specify argument ``concurrency`` instead. For more information, see https://docs.ray.io/en/master/data/transforming-data.html#stateful-transforms.
# 2025-01-12 05:24:14,094	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in C:\Users\aurel\AppData\Local\Temp\ray\session_2025-01-11_19-27-00_140008_13532\logs\ray-data
# 2025-01-12 05:24:14,095	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary] -> ActorPoolMapOperator[Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap)]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadBinary->SplitBlocks(28) 1: 0.00 row [00:00, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 0.0B/2.5GB object store: : 0.00 row [00:05, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 591.4KB object store: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 591.4KB object store: : 1.00 row [00:01, 1.04s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 591.4KB object store: : 1.00 row [00:01, 1.04s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 19; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
#
# Running Dataset. Active & requested resources: 2/14 CPU, 256.6MB/2.5GB object store: : 0.00 row [00:06, ? row/s] 19; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 544.1KB object store: : 1.00 row [00:02, 1.04s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 544.1KB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.04s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 544.1KB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.04s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
#
# ✔️  Dataset execution finished in 8.36 seconds: 100%|██████████| 2.00/2.00 [00:08<00:00, 4.21s/ row]07, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 544.1KB object store: 100%|██████████| 1.00/1.00 [00:03<00:00, 1.04s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:03, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:03<00:00, 1.04s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:03<00:00, 1.04s/ row]
#
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:03<00:00, 3.21s/ row]
#
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:03, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: : 0.00 row [00:03, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]:   0%|          | 0.00/2.00 [00:03<?, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:03<00:00, 1.62s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:03<00:00, 1.62s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:03<00:00, 1.64s/ row]
# Error during summarization: 'Chat' object has no attribute 'completion'
# 2025-01-12 05:24:23,356	WARNING util.py:587 -- The argument ``compute`` is deprecated in Ray 2.9. Please specify argument ``concurrency`` instead. For more information, see https://docs.ray.io/en/master/data/transforming-data.html#stateful-transforms.
# 2025-01-12 05:24:23,369	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in C:\Users\aurel\AppData\Local\Temp\ray\session_2025-01-11_19-27-00_140008_13532\logs\ray-data
# 2025-01-12 05:24:23,370	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary] -> ActorPoolMapOperator[Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap)]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadBinary->SplitBlocks(28) 1: 0.00 row [00:00, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 0.0B/2.5GB object store: : 0.00 row [00:05, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 6.4MB object store: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 6.4MB object store: : 1.00 row [00:01, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 6.4MB object store: : 1.00 row [00:01, 1.08s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 17; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
#
# Running Dataset. Active & requested resources: 2/14 CPU, 262.4MB/2.5GB object store: : 0.00 row [00:06, ? row/s] 17; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:02, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.08s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:07, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: 100%|██████████| 1.00/1.00 [00:03<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:08, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:03, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: 100%|██████████| 1.00/1.00 [00:04<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:10, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:04, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: 100%|██████████| 1.00/1.00 [00:05<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:11, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:05, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: 100%|██████████| 1.00/1.00 [00:06<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:12, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: 100%|██████████| 1.00/1.00 [00:07<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:13, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:07, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: 100%|██████████| 1.00/1.00 [00:08<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:14, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:08, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: 100%|██████████| 1.00/1.00 [00:09<00:00, 1.08s/ row]
#
#                                                                                                                  24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:09, ? row/s]
#
#
# ✔️  Dataset execution finished in 15.60 seconds: 100%|██████████| 2.00/2.00 [00:15<00:00, 7.82s/ row]
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: 100%|██████████| 1.00/1.00 [00:09<00:00, 1.08s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:09, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:09<00:00, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:09<00:00, 9.93s/ row]
#
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:09, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: : 0.00 row [00:09, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]:   0%|          | 0.00/2.00 [00:09<?, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:09<00:00, 4.97s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:09<00:00, 4.97s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:09<00:00, 4.98s/ row]
# 2025-01-12 05:24:39,468	WARNING util.py:587 -- The argument ``compute`` is deprecated in Ray 2.9. Please specify argument ``concurrency`` instead. For more information, see https://docs.ray.io/en/master/data/transforming-data.html#stateful-transforms.
# 2025-01-12 05:24:39,487	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in C:\Users\aurel\AppData\Local\Temp\ray\session_2025-01-11_19-27-00_140008_13532\logs\ray-data
# 2025-01-12 05:24:39,488	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary] -> ActorPoolMapOperator[Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap)]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadBinary->SplitBlocks(28) 1: 0.00 row [00:00, ? row/s]
#
# Running Dataset. Active & requested resources: 2/14 CPU, 262.4MB/2.5GB object store: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 6.4MB object store: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 6.4MB object store: : 1.00 row [00:01, 1.07s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 6.4MB object store: : 1.00 row [00:01, 1.07s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:02, 1.07s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:02, 1.07s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:07, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:03, 1.07s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:08, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:03, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:04, 1.07s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:09, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:04, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:05, 1.07s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:10, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:05, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:06, 1.07s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:11, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:07, 1.07s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:12, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:07, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:08, 1.07s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:13, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:08, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:09, 1.07s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 261.8MB/2.5GB object store: : 0.00 row [00:14, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:09, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:10, 1.07s/ row]
#
# ✔️  Dataset execution finished in 16.81 seconds: 100%|██████████| 2.00/2.00 [00:16<00:00, 8.43s/ row]5, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:10, ? row/s]
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 5.8MB object store: : 1.00 row [00:11, 1.07s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:11, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 1.00 row [00:11, 1.07s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 1.00 row [00:11, 1.07s/ row]
#
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 1.00 row [00:11, 11.3s/ row]
#
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:11, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: : 0.00 row [00:11, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]:   0%|          | 0.00/2.00 [00:11<?, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:11<00:00, 5.68s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:11<00:00, 5.68s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:11<00:00, 5.69s/ row]
# Error during summarization: 'Chat' object has no attribute 'completion'
# 2025-01-12 05:24:56,999	WARNING util.py:587 -- The argument ``compute`` is deprecated in Ray 2.9. Please specify argument ``concurrency`` instead. For more information, see https://docs.ray.io/en/master/data/transforming-data.html#stateful-transforms.
# 2025-01-12 05:24:57,015	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in C:\Users\aurel\AppData\Local\Temp\ray\session_2025-01-11_19-27-00_140008_13532\logs\ray-data
# 2025-01-12 05:24:57,017	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary] -> ActorPoolMapOperator[Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap)]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadBinary->SplitBlocks(28) 1: 0.00 row [00:00, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 0.0B/2.5GB object store: : 0.00 row [00:05, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 5.0MB object store: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 5.0MB object store: : 1.00 row [00:01, 1.06s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 5.0MB object store: : 1.00 row [00:01, 1.06s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
#
# Running Dataset. Active & requested resources: 2/14 CPU, 261.0MB/2.5GB object store: : 0.00 row [00:06, ? row/s] 16; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: : 1.00 row [00:02, 1.06s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: : 1.00 row [00:02, 1.06s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:07, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: : 1.00 row [00:03, 1.06s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:08, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:03, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: : 1.00 row [00:04, 1.06s/ row]
#
# ...
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 582.4KB object store; [locality off]:   0%|          | 0.00/7.00 [00:09<?, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 582.4KB object store; [locality off]:  29%|██▊       | 2.00/7.00 [00:09<00:23, 4.72s/ row]
#
# ✔️  Dataset execution finished in 15.40 seconds: 100%|██████████| 2.00/2.00 [00:15<00:00, 7.71s/ row]00/7.00 [00:15<00:38, 7.63s/ row]U, 582.4KB object store; [locality off]:  29%|██▊       | 2.00/7.00 [00:09<00:23, 4.72s/ row]
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 1.00 row [00:09, 1.07s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 582.4KB object store; [locality off]:  29%|██▊       | 2.00/7.00 [00:09<00:23, 4.72s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: : 1.00 row [00:09, 9.74s/ row]
#
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 16; Resources: 1.0 CPU, 582.4KB object store; [locality off]:  29%|██▊       | 2.00/7.00 [00:09<00:23, 4.72s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]:  29%|██▊       | 2.00/7.00 [00:09<00:23, 4.72s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:09<00:00, 4.72s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:09<00:00, 4.72s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:09<00:00, 4.89s/ row]
# Error during summarization: 'Chat' object has no attribute 'completion'
# 2025-01-12 05:25:28,688	WARNING util.py:587 -- The argument ``compute`` is deprecated in Ray 2.9. Please specify argument ``concurrency`` instead. For more information, see https://docs.ray.io/en/master/data/transforming-data.html#stateful-transforms.
# 2025-01-12 05:25:28,704	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in C:\Users\aurel\AppData\Local\Temp\ray\session_2025-01-11_19-27-00_140008_13532\logs\ray-data
# 2025-01-12 05:25:28,705	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary] -> ActorPoolMapOperator[Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap)]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadBinary->SplitBlocks(28) 1: 0.00 row [00:00, ? row/s]
#
# Running Dataset. Active & requested resources: 2/14 CPU, 261.0MB/2.5GB object store: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 5.0MB object store: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 5.0MB object store: : 1.00 row [00:01, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 5.0MB object store: : 1.00 row [00:01, 1.08s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 15; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 15; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: : 1.00 row [00:02, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.08s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:07, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:03<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:08, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:03, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:04<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:09, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:04, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:05<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:10, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:05, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:06<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:11, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:07<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:12, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:07, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:08<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:13, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:08, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:09<00:00, 1.08s/ row]
#
# ✔️  Dataset execution finished in 15.80 seconds: 100%|██████████| 2.00/2.00 [00:15<00:00, 7.93s/ row]5, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:09, ? row/s]
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:10<00:00, 1.08s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:10, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:10<00:00, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:10<00:00, 10.4s/ row]
#
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:10, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: : 0.00 row [00:10, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]:   0%|          | 0.00/2.00 [00:10<?, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:10<00:00, 5.20s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:10<00:00, 5.20s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:10<00:00, 5.22s/ row]
# 2025-01-12 05:25:44,780	WARNING util.py:587 -- The argument ``compute`` is deprecated in Ray 2.9. Please specify argument ``concurrency`` instead. For more information, see https://docs.ray.io/en/master/data/transforming-data.html#stateful-transforms.
# 2025-01-12 05:25:44,787	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in C:\Users\aurel\AppData\Local\Temp\ray\session_2025-01-11_19-27-00_140008_13532\logs\ray-data
# 2025-01-12 05:25:44,788	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary] -> ActorPoolMapOperator[Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap)]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadBinary->SplitBlocks(28) 1: 0.00 row [00:00, ? row/s]
#
# Running Dataset. Active & requested resources: 2/14 CPU, 261.0MB/2.5GB object store: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 5.0MB object store: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 5.0MB object store: : 1.00 row [00:01, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 1; Queued blocks: 0; Resources: 1.0 CPU, 5.0MB object store: : 1.00 row [00:01, 1.08s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 15; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 15; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:01, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: : 1.00 row [00:02, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:02<00:00, 1.08s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:07, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:02, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:03<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:08, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:03, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:04<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:09, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:04, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:05<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:10, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:05, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:06<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:11, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:06, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:07<00:00, 1.08s/ row]
#
# Running Dataset. Active & requested resources: 1/14 CPU, 260.5MB/2.5GB object store: : 0.00 row [00:13, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:07, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:08<00:00, 1.08s/ row]
#
# ✔️  Dataset execution finished in 14.45 seconds: 100%|██████████| 2.00/2.00 [00:14<00:00, 7.27s/ row]4, ? row/s] 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:08, ? row/s]
#
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 4.5MB object store: 100%|██████████| 1.00/1.00 [00:08<00:00, 1.08s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:08, ? row/s]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:08<00:00, 1.08s/ row]
# - ReadBinary->SplitBlocks(28): Tasks: 0; Queued blocks: 0; Resources: 0.0 CPU, 0.0B object store: 100%|██████████| 1.00/1.00 [00:08<00:00, 8.95s/ row]
#
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 4; Actors: 1; Queued blocks: 24; Resources: 1.0 CPU, 256.0MB object store; [locality off]: : 0.00 row [00:08, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: : 0.00 row [00:08, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]:   0%|          | 0.00/2.00 [00:08<?, ? row/s]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:09<00:00, 4.50s/ row]
#
# - Map(BinaryScan._to_document)->MapBatches(BaseMapTransformCallable___wrap): Tasks: 0; Actors: 0; Queued blocks: 0; Resources: 1.0 CPU, 0.0B object store; [locality off]: 100%|██████████| 2.00/2.00 [00:09<00:00, 4.51s/ row]
# Error during summarization: 'Chat' object has no attribute 'completion'

# %%
print(result)
# Out:
# [([-0.0006984524, -0.019356806, -0.032198977, 0.012672074, -0.039972313, -0.00816881, 0.010129155, 0.08035286, 0.0011332576, 0.015631726, -0.029154275, 0.028592963, -0.028252771, 0.014925832, -0.0019645968, -0.0017487888, -0.030821206, 0.0074203922, -0.03160364, 0.02056448, 0.020003166, -0.01465368, -0.06973893, 0.03435918, 0.013097311, -0.04136709, -0.0136926435, 0.0067272554, -0.017774923, 0.0016573627, 0.028422868, 0.03160364, -0.001843404, 0.02934138, -0.017111553, 0.0064551034, -0.010639439, -0.037182756, -0.005515329, 0.015104432, -0.012034218, -0.0023792032, -0.020292329, 0.021704117, -0.0015903878, 0.02456171, 0.020122234, -0.0012810277, 0.0076372633, 0.00875989, -0.020938689, -0.034240115, -0.008640824, -0.0015308546, -0.021074764, -0.022894781, 0.014245452, -0.056131337, -0.0038016222, -0.024459654, 0.009516813, -0.00084569084, -0.013454511, 0.011991695, 0.010809534, 0.00041061986, 0.0026088313, -0.017672867, 0.018999606, 0.05456646, 0.009695413, 0.011209258, 0.011030658, 0.036910605, 0.008657834, -0.022537582, 0.017774923, 0.011991695, -0.007097212, 0.008385682, 0.0029745356, -0.03881567, -0.016720334, 0.030293912, -0.012910207, 0.002479134, -0.00400361, -0.13485128, 0.0143305, 0.012757122, 0.015121441, 0.005991595, 0.03473339, -0.012731607, 0.021789163, -0.020938689, -0.021806173, 0.0030128069, -0.047048263, -0.0022537583, 0.034546286, -0.016847905, 0.02864399, 0.006153185, -0.016167525, 0.022639638, -0.014874804, 0.019833071, -0.010894582, 0.0042502475, -0.0077946014, -0.011039163, -0.01986709, -0.005153877, -0.030106807, 0.0044309734, -0.020122234, -0.030191854, -0.017570809, -0.012195808, 0.024085445, -0.04085681, -0.007701049, 0.017392209, -0.0033933944, -0.0080625005, -0.037284814, -0.018030066, -0.04698023, 0.018353246, -0.017757913, -0.006302018, -0.026670888, 0.025718357, -0.010886077, -0.025344148, -0.021823183, 0.035481807, -0.04759257, -0.029970732, -0.0343932, 0.008955499, 0.0066932365, 0.0012374409, -0.01734118, -0.022027297, 0.021891221, -0.0036230225, 0.0058640237, -0.02124486, 0.03204589, -0.005855519, 0.009219146, -0.009074566, 0.020785604, 0.0094827935, 0.011532438, -0.033559736, 0.010205697, 0.032573182, -0.008139044, 0.003878165, -0.038373422, 0.017018, -0.020768594, -0.015954906, 0.012136275, -0.008355915, 0.013029274, 0.022112343, -0.02423853, 0.03844146, 0.026534813, -0.004881725, 0.0055323383, 0.05504273, -0.0028958665, 0.008236848, 0.033457678, -0.0038037484, 0.053137664, 0.014806766, 0.014526109, 0.004012115, -0.0059958473, -0.008470729, -0.005357991, 0.033780858, -0.019441854, -0.055484973, -0.00046908998, -0.044190668, -0.00420985, -0.050756335, 0.035175636, -0.012382912, -0.0076032444, 0.004779668, -0.010146164, 0.007875397, 0.013913767, 0.015861355, 0.015844345, -0.065690674, 0.026109576, -0.024714798, -0.010860563, 0.008827928, -0.0010253537, 0.03298141, -0.013616101, -0.04959969, -0.017451743, -0.013896758, -0.0040971623, 0.064295895, -0.0417413, -0.006642208, 0.009185128, 0.0044990117, -0.0005825752, -0.0053835055, 0.027844545, 0.037625004, -0.02900119, -0.024697788, 0.01399031, 0.036570415, 0.014679194, 0.009355223, -0.043442253, -0.016558744, -0.017825952, 0.03980222, -0.027572392, -0.0035741203, 0.02294581, -0.010324764, 0.04021045, 0.035209656, -0.011413371, 0.0069526313, -0.016992485, -0.0283038, 0.027912581, -0.022877771, -0.026909022, -0.026245652, -0.0039100577, -0.017502772, 0.016720334, 0.0069994074, 0.04749051, 0.008360167, 0.023354037, 0.012748617, -0.018931568, 0.014083862, -0.008568534, -0.0075479634, 0.033576746, 0.036434337, 0.015895374, 0.021687107, 0.010324764, 0.0069101076, -0.027419306, -0.044768993, -0.0036889343, -0.028831095, 0.035277694, -0.0026428504, -0.0094827935, -0.009729431, 0.024068436, 0.013939282, -0.011183743, 0.011430381, 0.006004352, -0.0015191606, -0.004348052, 0.0051836437, 0.03881567, -0.014900318, -0.020462424, -0.0028575952, -0.045959655, -0.00976345, -0.022299448, -0.0020273193, -0.023286, -0.009066061, 0.02430657, 0.035821997, -0.01214478,  ...

# %%
import json

with open('result.json', 'w') as f:
    json.dump(result, f, indent=4)
